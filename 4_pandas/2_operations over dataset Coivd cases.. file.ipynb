# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Covid cases in India.xlsx')
df
#if you wish to read .tsv file than pd.read_csv('dataset.tsv', delimiter = '\t') 
#tsv file mean "tab separated values file"
#csv file mean "comma-separated values file"
# Out:
#     S. No.                        Name of State / UT  ...  Recovered  Deaths
# 0      1.0                               Maharashtra  ...       3800     779
# 1      2.0                                   Gujarat  ...       2091     472
# 2      3.0                                     Delhi  ...       2020      68
# 3      4.0                                Tamil Nadu  ...       1824      44
# 4      5.0                                 Rajasthan  ...       2176     107
# 5      6.0                            Madhya Pradesh  ...       1480     211
# 6      7.0                             Uttar Pradesh  ...       1499      74
# 7      8.0                            Andhra Pradesh  ...        887      44
# 8      9.0                               West Bengal  ...        372     171
# 9     10.0                                    Punjab  ...        157      31
# 10    11.0                                 Telangana  ...        751      30
# 11    12.0                         Jammu and Kashmir  ...        368       9
# 12    13.0                                 Karnataka  ...        386      30
# 13    14.0                                   Haryana  ...        290       9
# 14    15.0                                     Bihar  ...        318       5
# 15    16.0                                    Kerala  ...        485       4
# 16    17.0                                    Odisha  ...         68       3
# 17    18.0                                Chandigarh  ...         24       2
# 18    19.0                                 Jharkhand  ...         78       3
# 19    20.0                                   Tripura  ...          2       0
# 20    21.0                               Uttarakhand  ...         46       1
# 21    22.0                                     Assam  ...         35       1
# 22    23.0                              Chhattisgarh  ...         43       0
# 23    24.0                          Himachal Pradesh  ...         35       3
# 24    25.0                                    Ladakh  ...         18       0
# 25    26.0               Andaman and Nicobar Islands  ...         33       0
# 26    27.0                                 Meghalaya  ...         10       1
# 27    28.0                                Puducherry  ...          8       0
# 28    29.0                                       Goa  ...          7       0
# 29    30.0                                   Manipur  ...          2       0
# 30    31.0                                   Mizoram  ...          1       0
# 31    32.0                         Arunachal Pradesh  ...          1       0
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu  ...          0       0
# 33     NaN                                     Total  ...      19315    2102
#
# [34 rows x 6 columns]

# %%
#in "Covid cases in India.xlsx" file tow sheets are available
#you want to open separated sheet then follow this
df1 = pd.read_excel('/content/Covid cases in India.xlsx',sheet_name='Sheet2')
df1
# Out:
#                                       S. No.  ... Death.1
# 0                                        NaN  ...     NaN
# 1                                          1  ...     0.0
# 2                                          2  ...     0.0
# 3                                          3  ...     1.0
# 4                                          4  ...     0.0
# 5                                          5  ...     0.0
# 6                                          6  ...     1.0
# 7                                          7  ...     0.0
# 8                                          8  ...     1.0
# 9                                          9  ...     0.0
# 10                                        10  ...     0.0
# 11                                        11  ...     1.0
# 12                                        12  ...     0.0
# 13                                        13  ...     0.0
# 14                                        14  ...     0.0
# 15                                        15  ...     0.0
# 16  Total number of confirmed cases in India  ...     0.0
# 17                                       NaN  ...     0.0
# 18                                       NaN  ...     0.0
# 19                                       NaN  ...     0.0
# 20                                       NaN  ...     0.0
#
# [21 rows x 13 columns]

# %%
df.columns
# Out:
# Index(['S. No.', 'Name of State / UT', 'TotalConfirmedCases', 'Active',
#        'Recovered', 'Deaths'],
#       dtype='object')

# %%
df.columns[1:4]
# Out:
# Index(['Name of State / UT', 'TotalConfirmedCases', 'Active'], dtype='object')

# %%
df.Active[1:6]
# Out:
# 1    5234
# 2    4454
# 3    4667
# 4    1458
# 5    1766
# Name: Active, dtype: int64

# %%
df[['Active','Recovered']][3:10]
# Out:
#    Active  Recovered
# 3    4667       1824
# 4    1458       2176
# 5    1766       1480
# 6    1800       1499
# 7     999        887
# 8    1243        372
# 9    1574        157

# %%
#you can also use this oparetion for display column
df[df.columns[1:3]][2:10]
# Out:
#   Name of State / UT  TotalConfirmedCases
# 2              Delhi                 6542
# 3         Tamil Nadu                 6535
# 4          Rajasthan                 3741
# 5     Madhya Pradesh                 3457
# 6      Uttar Pradesh                 3373
# 7     Andhra Pradesh                 1930
# 8        West Bengal                 1786
# 9             Punjab                 1762

# %%
df.shape
# Out:
# (34, 6)

# %%
new_df = df
new_df.shape
# Out:
# (34, 6)

# %%
new_df = df[10:19]
new_df
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 10    11.0          Telangana                 1163     382        751      30
# 11    12.0  Jammu and Kashmir                  836     459        368       9
# 12    13.0          Karnataka                  794     377        386      30
# 13    14.0            Haryana                  675     376        290       9
# 14    15.0              Bihar                  629     306        318       5
# 15    16.0             Kerala                  506      17        485       4
# 16    17.0             Odisha                  352     281         68       3
# 17    18.0         Chandigarh                  169     143         24       2
# 18    19.0          Jharkhand                  156      75         78       3

# %%
#find particular row and column as o/p
df.loc[0,'Active']
# Out:
# 15649

# %%
df.loc[1:5,'Active']
# Out:
# 1    5234
# 2    4454
# 3    4667
# 4    1458
# 5    1766
# Name: Active, dtype: int64

# %%
  #find >500 active cases
  df['Active'] > 500
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# Name: Active, dtype: bool

# %%
df.loc[df['Active']>500]
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 0      1.0        Maharashtra                20228   15649       3800     779
# 1      2.0            Gujarat                 7797    5234       2091     472
# 2      3.0              Delhi                 6542    4454       2020      68
# 3      4.0         Tamil Nadu                 6535    4667       1824      44
# 4      5.0          Rajasthan                 3741    1458       2176     107
# 5      6.0     Madhya Pradesh                 3457    1766       1480     211
# 6      7.0      Uttar Pradesh                 3373    1800       1499      74
# 7      8.0     Andhra Pradesh                 1930     999        887      44
# 8      9.0        West Bengal                 1786    1243        372     171
# 9     10.0             Punjab                 1762    1574        157      31
# 33     NaN              Total                62916   41495      19315    2102

# %%
#find >500 active cases and print there states and deaths only
df.loc[df['Active']>500,['Name of State / UT','Active','Deaths']]
# Out:
#    Name of State / UT  Active  Deaths
# 0         Maharashtra   15649     779
# 1             Gujarat    5234     472
# 2               Delhi    4454      68
# 3          Tamil Nadu    4667      44
# 4           Rajasthan    1458     107
# 5      Madhya Pradesh    1766     211
# 6       Uttar Pradesh    1800      74
# 7      Andhra Pradesh     999      44
# 8         West Bengal    1243     171
# 9              Punjab    1574      31
# 33              Total   41495    2102

# %%
df.loc[df['Active']>500][['Name of State / UT','Active','Deaths']]
# Out:
#    Name of State / UT  Active  Deaths
# 0         Maharashtra   15649     779
# 1             Gujarat    5234     472
# 2               Delhi    4454      68
# 3          Tamil Nadu    4667      44
# 4           Rajasthan    1458     107
# 5      Madhya Pradesh    1766     211
# 6       Uttar Pradesh    1800      74
# 7      Andhra Pradesh     999      44
# 8         West Bengal    1243     171
# 9              Punjab    1574      31
# 33              Total   41495    2102

# %%
#you can find by index locations and print same things you use iloc
df.iloc[(df['Active']>500).values,[1,3,5]]

#in this input [1,3,5] is column location
# Out:
#    Name of State / UT  Active  Deaths
# 0         Maharashtra   15649     779
# 1             Gujarat    5234     472
# 2               Delhi    4454      68
# 3          Tamil Nadu    4667      44
# 4           Rajasthan    1458     107
# 5      Madhya Pradesh    1766     211
# 6       Uttar Pradesh    1800      74
# 7      Andhra Pradesh     999      44
# 8         West Bengal    1243     171
# 9              Punjab    1574      31
# 33              Total   41495    2102

# %%
#you can use multile query with &(and) 
df.iloc[(df['Active']>500).values & (df['Deaths']>100).values,[1,3,5]]

#you want to print all column then perform df.iloc[(df['Active']>500).values & (df['Deaths']>100).values]
# Out:
#    Name of State / UT  Active  Deaths
# 0         Maharashtra   15649     779
# 1             Gujarat    5234     472
# 4           Rajasthan    1458     107
# 5      Madhya Pradesh    1766     211
# 8         West Bengal    1243     171
# 33              Total   41495    2102

# %%
##you can use multile query with | (or)
df.iloc[(df['Active']>500).values | (df['Deaths']>100).values,[1,3,5]]
# Out:
#    Name of State / UT  Active  Deaths
# 0         Maharashtra   15649     779
# 1             Gujarat    5234     472
# 2               Delhi    4454      68
# 3          Tamil Nadu    4667      44
# 4           Rajasthan    1458     107
# 5      Madhya Pradesh    1766     211
# 6       Uttar Pradesh    1800      74
# 7      Andhra Pradesh     999      44
# 8         West Bengal    1243     171
# 9              Punjab    1574      31
# 33              Total   41495    2102

# %%
#disply 6 states with maximum deaths
df.sort_values('Deaths',ascending=False).head(6)
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 33     NaN              Total                62916   41495      19315    2102
# 0      1.0        Maharashtra                20228   15649       3800     779
# 1      2.0            Gujarat                 7797    5234       2091     472
# 5      6.0     Madhya Pradesh                 3457    1766       1480     211
# 8      9.0        West Bengal                 1786    1243        372     171
# 4      5.0          Rajasthan                 3741    1458       2176     107

# %%
#you can also use for disply 6 states with maximum deaths
df.nlargest(6,'Deaths')
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 33     NaN              Total                62916   41495      19315    2102
# 0      1.0        Maharashtra                20228   15649       3800     779
# 1      2.0            Gujarat                 7797    5234       2091     472
# 5      6.0     Madhya Pradesh                 3457    1766       1480     211
# 8      9.0        West Bengal                 1786    1243        372     171
# 4      5.0          Rajasthan                 3741    1458       2176     107

# %%
#disply 6 states with minimum deaths
df.sort_values('Deaths').head(6)
# Out:
#     S. No.           Name of State / UT  ...  Recovered  Deaths
# 31    32.0            Arunachal Pradesh  ...          1       0
# 29    30.0                      Manipur  ...          2       0
# 28    29.0                          Goa  ...          7       0
# 27    28.0                   Puducherry  ...          8       0
# 25    26.0  Andaman and Nicobar Islands  ...         33       0
# 24    25.0                       Ladakh  ...         18       0
#
# [6 rows x 6 columns]

# %%
#you can also use for disply 6 states with minimum deaths
df.nsmallest(6,'Deaths')
# Out:
#     S. No.           Name of State / UT  ...  Recovered  Deaths
# 19    20.0                      Tripura  ...          2       0
# 22    23.0                 Chhattisgarh  ...         43       0
# 24    25.0                       Ladakh  ...         18       0
# 25    26.0  Andaman and Nicobar Islands  ...         33       0
# 27    28.0                   Puducherry  ...          8       0
# 28    29.0                          Goa  ...          7       0
#
# [6 rows x 6 columns]

# %%
#0 Deaths of states
df.iloc[(df['Deaths']==0).values,[1,5]].reset_index()
# Out:
#    index                        Name of State / UT  Deaths
# 0     19                                   Tripura       0
# 1     22                              Chhattisgarh       0
# 2     24                                    Ladakh       0
# 3     25               Andaman and Nicobar Islands       0
# 4     27                                Puducherry       0
# 5     28                                       Goa       0
# 6     29                                   Manipur       0
# 7     30                                   Mizoram       0
# 8     31                         Arunachal Pradesh       0
# 9     32  Dadra and Nagar Haveli and Daman and Diu       0

# %%
#you write frac = 0.5 then 50% dataset print random (frac= fraction)
df.sample(frac = 0.5)
# Out:
#     S. No. Name of State / UT  TotalConfirmedCases  Active  Recovered  Deaths
# 8      9.0        West Bengal                 1786    1243        372     171
# 24    25.0             Ladakh                   42      24         18       0
# 28    29.0                Goa                    7       0          7       0
# 1      2.0            Gujarat                 7797    5234       2091     472
# 29    30.0            Manipur                    2       0          2       0
# 3      4.0         Tamil Nadu                 6535    4667       1824      44
# 21    22.0              Assam                   62      26         35       1
# 30    31.0            Mizoram                    1       0          1       0
# 12    13.0          Karnataka                  794     377        386      30
# 2      3.0              Delhi                 6542    4454       2020      68
# 6      7.0      Uttar Pradesh                 3373    1800       1499      74
# 22    23.0       Chhattisgarh                   59      16         43       0
# 23    24.0   Himachal Pradesh                   52      11         35       3
# 7      8.0     Andhra Pradesh                 1930     999        887      44
# 33     NaN              Total                62916   41495      19315    2102
# 18    19.0          Jharkhand                  156      75         78       3
# 31    32.0  Arunachal Pradesh                    1       0          1       0

# %%
#find out total of total confirmed cases of all states
df['TotalConfirmedCases'].sum()

#but at that time toal also included
# Out:
# 125832

# %%
#in this case total is rigth bcz i choose 0 to 32 row in df
df['TotalConfirmedCases'][:-1].sum()
# Out:
# 62916

# %%
#delete column and use axis = 1 for column 
df.drop('TotalConfirmedCases',axis=1)

#you can use "df.drop('TotalConfirmedCases',axis=1,inplace = True)" than changes are permanently sotre in df
# Out:
#     S. No.                        Name of State / UT  Active  Recovered  Deaths
# 0      1.0                               Maharashtra   15649       3800     779
# 1      2.0                                   Gujarat    5234       2091     472
# 2      3.0                                     Delhi    4454       2020      68
# 3      4.0                                Tamil Nadu    4667       1824      44
# 4      5.0                                 Rajasthan    1458       2176     107
# 5      6.0                            Madhya Pradesh    1766       1480     211
# 6      7.0                             Uttar Pradesh    1800       1499      74
# 7      8.0                            Andhra Pradesh     999        887      44
# 8      9.0                               West Bengal    1243        372     171
# 9     10.0                                    Punjab    1574        157      31
# 10    11.0                                 Telangana     382        751      30
# 11    12.0                         Jammu and Kashmir     459        368       9
# 12    13.0                                 Karnataka     377        386      30
# 13    14.0                                   Haryana     376        290       9
# 14    15.0                                     Bihar     306        318       5
# 15    16.0                                    Kerala      17        485       4
# 16    17.0                                    Odisha     281         68       3
# 17    18.0                                Chandigarh     143         24       2
# 18    19.0                                 Jharkhand      75         78       3
# 19    20.0                                   Tripura     133          2       0
# 20    21.0                               Uttarakhand      20         46       1
# 21    22.0                                     Assam      26         35       1
# 22    23.0                              Chhattisgarh      16         43       0
# 23    24.0                          Himachal Pradesh      11         35       3
# 24    25.0                                    Ladakh      24         18       0
# 25    26.0               Andaman and Nicobar Islands       0         33       0
# 26    27.0                                 Meghalaya       2         10       1
# 27    28.0                                Puducherry       2          8       0
# 28    29.0                                       Goa       0          7       0
# 29    30.0                                   Manipur       0          2       0
# 30    31.0                                   Mizoram       0          1       0
# 31    32.0                         Arunachal Pradesh       0          1       0
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu       1          0       0
# 33     NaN                                     Total   41495      19315    2102

# %%
#delete row and use axis = 0 for row
df.drop([0,2,4,6,8,10],axis=0)

#delete single row then use "df.drop(1,axis=0)"
# Out:
#     S. No.                        Name of State / UT  ...  Recovered  Deaths
# 1      2.0                                   Gujarat  ...       2091     472
# 3      4.0                                Tamil Nadu  ...       1824      44
# 5      6.0                            Madhya Pradesh  ...       1480     211
# 7      8.0                            Andhra Pradesh  ...        887      44
# 9     10.0                                    Punjab  ...        157      31
# 11    12.0                         Jammu and Kashmir  ...        368       9
# 12    13.0                                 Karnataka  ...        386      30
# 13    14.0                                   Haryana  ...        290       9
# 14    15.0                                     Bihar  ...        318       5
# 15    16.0                                    Kerala  ...        485       4
# 16    17.0                                    Odisha  ...         68       3
# 17    18.0                                Chandigarh  ...         24       2
# 18    19.0                                 Jharkhand  ...         78       3
# 19    20.0                                   Tripura  ...          2       0
# 20    21.0                               Uttarakhand  ...         46       1
# 21    22.0                                     Assam  ...         35       1
# 22    23.0                              Chhattisgarh  ...         43       0
# 23    24.0                          Himachal Pradesh  ...         35       3
# 24    25.0                                    Ladakh  ...         18       0
# 25    26.0               Andaman and Nicobar Islands  ...         33       0
# 26    27.0                                 Meghalaya  ...         10       1
# 27    28.0                                Puducherry  ...          8       0
# 28    29.0                                       Goa  ...          7       0
# 29    30.0                                   Manipur  ...          2       0
# 30    31.0                                   Mizoram  ...          1       0
# 31    32.0                         Arunachal Pradesh  ...          1       0
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu  ...          0       0
# 33     NaN                                     Total  ...      19315    2102
#
# [28 rows x 6 columns]

# %%
#create new column and add
df['Total_cases'] = df['Active'] + df['Recovered'] + df['Deaths']
df
# Out:
#     S. No.                        Name of State / UT  ...  Deaths  Total_cases
# 0      1.0                               Maharashtra  ...     779        20228
# 1      2.0                                   Gujarat  ...     472         7797
# 2      3.0                                     Delhi  ...      68         6542
# 3      4.0                                Tamil Nadu  ...      44         6535
# 4      5.0                                 Rajasthan  ...     107         3741
# 5      6.0                            Madhya Pradesh  ...     211         3457
# 6      7.0                             Uttar Pradesh  ...      74         3373
# 7      8.0                            Andhra Pradesh  ...      44         1930
# 8      9.0                               West Bengal  ...     171         1786
# 9     10.0                                    Punjab  ...      31         1762
# 10    11.0                                 Telangana  ...      30         1163
# 11    12.0                         Jammu and Kashmir  ...       9          836
# 12    13.0                                 Karnataka  ...      30          793
# 13    14.0                                   Haryana  ...       9          675
# 14    15.0                                     Bihar  ...       5          629
# 15    16.0                                    Kerala  ...       4          506
# 16    17.0                                    Odisha  ...       3          352
# 17    18.0                                Chandigarh  ...       2          169
# 18    19.0                                 Jharkhand  ...       3          156
# 19    20.0                                   Tripura  ...       0          135
# 20    21.0                               Uttarakhand  ...       1           67
# 21    22.0                                     Assam  ...       1           62
# 22    23.0                              Chhattisgarh  ...       0           59
# 23    24.0                          Himachal Pradesh  ...       3           49
# 24    25.0                                    Ladakh  ...       0           42
# 25    26.0               Andaman and Nicobar Islands  ...       0           33
# 26    27.0                                 Meghalaya  ...       1           13
# 27    28.0                                Puducherry  ...       0           10
# 28    29.0                                       Goa  ...       0            7
# 29    30.0                                   Manipur  ...       0            2
# 30    31.0                                   Mizoram  ...       0            1
# 31    32.0                         Arunachal Pradesh  ...       0            1
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu  ...       0            1
# 33     NaN                                     Total  ...    2102        62912
#
# [34 rows x 7 columns]

# %%
#you can perform any kind of mathematical calculation useing "numpy" library
import numpy as np

#i am create new copy of my data set
new_df = df

# %%
#you can remove value from new_df
new_df.iloc[1,2] = np.NaN
new_df.head()
# Out:
#    S. No. Name of State / UT  ...  Deaths  Total_cases
# 0     1.0        Maharashtra  ...     779        20228
# 1     2.0            Gujarat  ...     472         7797
# 2     3.0              Delhi  ...      68         6542
# 3     4.0         Tamil Nadu  ...      44         6535
# 4     5.0          Rajasthan  ...     107         3741
#
# [5 rows x 7 columns]

# %%
#count NaN value
new_df.isnull().sum()
# Out:
# S. No.                 1
# Name of State / UT     0
# TotalConfirmedCases    1
# Active                 0
# Recovered              0
# Deaths                 0
# Total_cases            0
# dtype: int64

# %%
#remove NaN row in new_df
new_df = new_df.dropna()
new_df

#in our case 1 row and 33th row are removed because in this row NaN value are occur
# Out:
#     S. No.                        Name of State / UT  ...  Deaths  Total_cases
# 0      1.0                               Maharashtra  ...     779        20228
# 2      3.0                                     Delhi  ...      68         6542
# 3      4.0                                Tamil Nadu  ...      44         6535
# 4      5.0                                 Rajasthan  ...     107         3741
# 5      6.0                            Madhya Pradesh  ...     211         3457
# 6      7.0                             Uttar Pradesh  ...      74         3373
# 7      8.0                            Andhra Pradesh  ...      44         1930
# 8      9.0                               West Bengal  ...     171         1786
# 9     10.0                                    Punjab  ...      31         1762
# 10    11.0                                 Telangana  ...      30         1163
# 11    12.0                         Jammu and Kashmir  ...       9          836
# 12    13.0                                 Karnataka  ...      30          793
# 13    14.0                                   Haryana  ...       9          675
# 14    15.0                                     Bihar  ...       5          629
# 15    16.0                                    Kerala  ...       4          506
# 16    17.0                                    Odisha  ...       3          352
# 17    18.0                                Chandigarh  ...       2          169
# 18    19.0                                 Jharkhand  ...       3          156
# 19    20.0                                   Tripura  ...       0          135
# 20    21.0                               Uttarakhand  ...       1           67
# 21    22.0                                     Assam  ...       1           62
# 22    23.0                              Chhattisgarh  ...       0           59
# 23    24.0                          Himachal Pradesh  ...       3           49
# 24    25.0                                    Ladakh  ...       0           42
# 25    26.0               Andaman and Nicobar Islands  ...       0           33
# 26    27.0                                 Meghalaya  ...       1           13
# 27    28.0                                Puducherry  ...       0           10
# 28    29.0                                       Goa  ...       0            7
# 29    30.0                                   Manipur  ...       0            2
# 30    31.0                                   Mizoram  ...       0            1
# 31    32.0                         Arunachal Pradesh  ...       0            1
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu  ...       0            1
#
# [32 rows x 7 columns]

# %%
#reset index 
new_df.reset_index(inplace=True , drop=True)
new_df.head()

#use drop for remove old index and use inplace for permanently change your new_df
# Out:
#    S. No. Name of State / UT  ...  Deaths  Total_cases
# 0     1.0        Maharashtra  ...     779        20228
# 1     3.0              Delhi  ...      68         6542
# 2     4.0         Tamil Nadu  ...      44         6535
# 3     5.0          Rajasthan  ...     107         3741
# 4     6.0     Madhya Pradesh  ...     211         3457
#
# [5 rows x 7 columns]

# %%
new_df1 = df
new_df1.iloc[1:5,2] = np.NaN
new_df1.head(7)
# Out:
#    S. No. Name of State / UT  ...  Deaths  Total_cases
# 0     1.0        Maharashtra  ...     779        20228
# 1     2.0            Gujarat  ...     472         7797
# 2     3.0              Delhi  ...      68         6542
# 3     4.0         Tamil Nadu  ...      44         6535
# 4     5.0          Rajasthan  ...     107         3741
# 5     6.0     Madhya Pradesh  ...     211         3457
# 6     7.0      Uttar Pradesh  ...      74         3373
#
# [7 rows x 7 columns]

# %%
#fill NaN value with forward value
new_df1.fillna(method='ffill').head(7)
# Out:
#    S. No. Name of State / UT  ...  Deaths  Total_cases
# 0     1.0        Maharashtra  ...     779        20228
# 1     2.0            Gujarat  ...     472         7797
# 2     3.0              Delhi  ...      68         6542
# 3     4.0         Tamil Nadu  ...      44         6535
# 4     5.0          Rajasthan  ...     107         3741
# 5     6.0     Madhya Pradesh  ...     211         3457
# 6     7.0      Uttar Pradesh  ...      74         3373
#
# [7 rows x 7 columns]

# %%
#fill NaN value with backward value
new_df1.fillna(method='bfill').head(7)
# Out:
#    S. No. Name of State / UT  ...  Deaths  Total_cases
# 0     1.0        Maharashtra  ...     779        20228
# 1     2.0            Gujarat  ...     472         7797
# 2     3.0              Delhi  ...      68         6542
# 3     4.0         Tamil Nadu  ...      44         6535
# 4     5.0          Rajasthan  ...     107         3741
# 5     6.0     Madhya Pradesh  ...     211         3457
# 6     7.0      Uttar Pradesh  ...      74         3373
#
# [7 rows x 7 columns]

# %%
#NaN replace with "mean" value 
new_df1.fillna(value=new_df1.mean()).head(7)
# Out:
#    S. No. Name of State / UT  ...  Deaths  Total_cases
# 0     1.0        Maharashtra  ...     779        20228
# 1     2.0            Gujarat  ...     472         7797
# 2     3.0              Delhi  ...      68         6542
# 3     4.0         Tamil Nadu  ...      44         6535
# 4     5.0          Rajasthan  ...     107         3741
# 5     6.0     Madhya Pradesh  ...     211         3457
# 6     7.0      Uttar Pradesh  ...      74         3373
#
# [7 rows x 7 columns]

# %%
#you can change type of any column
new_df1['Active'].astype(float).head(5)
# Out:
# 0    15649.0
# 1     5234.0
# 2     4454.0
# 3     4667.0
# 4     1458.0
# Name: Active, dtype: float64

# %%
#you can see your df in graphical manner then use "matplotlib"
#you want to add more feature in graphical manner then use "seaborn" library 
#seaborn is next leavel or updated version of matplotlib
df1 = pd.read_excel('/content/Covid cases in India.xlsx')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#see graph of Active cases with there states
sns.barplot(x='Name of State / UT',y='Active',data=df1)

# %%
df1
# Out:
#     S. No.                        Name of State / UT  ...  Recovered  Deaths
# 0      1.0                               Maharashtra  ...       3800     779
# 1      2.0                                   Gujarat  ...       2091     472
# 2      3.0                                     Delhi  ...       2020      68
# 3      4.0                                Tamil Nadu  ...       1824      44
# 4      5.0                                 Rajasthan  ...       2176     107
# 5      6.0                            Madhya Pradesh  ...       1480     211
# 6      7.0                             Uttar Pradesh  ...       1499      74
# 7      8.0                            Andhra Pradesh  ...        887      44
# 8      9.0                               West Bengal  ...        372     171
# 9     10.0                                    Punjab  ...        157      31
# 10    11.0                                 Telangana  ...        751      30
# 11    12.0                         Jammu and Kashmir  ...        368       9
# 12    13.0                                 Karnataka  ...        386      30
# 13    14.0                                   Haryana  ...        290       9
# 14    15.0                                     Bihar  ...        318       5
# 15    16.0                                    Kerala  ...        485       4
# 16    17.0                                    Odisha  ...         68       3
# 17    18.0                                Chandigarh  ...         24       2
# 18    19.0                                 Jharkhand  ...         78       3
# 19    20.0                                   Tripura  ...          2       0
# 20    21.0                               Uttarakhand  ...         46       1
# 21    22.0                                     Assam  ...         35       1
# 22    23.0                              Chhattisgarh  ...         43       0
# 23    24.0                          Himachal Pradesh  ...         35       3
# 24    25.0                                    Ladakh  ...         18       0
# 25    26.0               Andaman and Nicobar Islands  ...         33       0
# 26    27.0                                 Meghalaya  ...         10       1
# 27    28.0                                Puducherry  ...          8       0
# 28    29.0                                       Goa  ...          7       0
# 29    30.0                                   Manipur  ...          2       0
# 30    31.0                                   Mizoram  ...          1       0
# 31    32.0                         Arunachal Pradesh  ...          1       0
# 32    33.0  Dadra and Nagar Haveli and Daman and Diu  ...          0       0
# 33     NaN                                     Total  ...      19315    2102
#
# [34 rows x 6 columns]

# %%
#you can increase you figure size
plt.figure(figsize=(16,8))
#in this df1 i write df1[:-1] for ignore total
sns.barplot(x='Name of State / UT',y='Active',data=df1[:-1])
#add xticks for some changes in x-axis and add rotation for rotat your value and you use "" horizontalalignment='right' "" for see well formate
plt.xticks(rotation=80,horizontalalignment='right',fontweight='light',fontsize='x-large')
plt.show()

# %%
#you can increase you figure size
plt.figure(figsize=(16,8))
#in this df1 i write df1[:-1] for ignore total
sns.barplot(x='Name of State / UT',y='Active',data=df1[:-1])
#add xticks for some changes in x-axis and add rotation for rotat your value and you use "" horizontalalignment='left' "" for see well formate
plt.xticks(rotation=-80,horizontalalignment='left',fontweight='light',fontsize='x-large')
plt.show()

# %%
#---------stripplot---------------------
#you can increase you figure size
plt.figure(figsize=(16,8))
#in this df1 i write df1[:-1] for ignore total
sns.stripplot(x='Name of State / UT',y='Active',data=df1[:-1])
#add xticks for some changes in x-axis and add rotation for rotat your value and you use "" horizontalalignment='right' "" for see well formate
plt.xticks(rotation=80,horizontalalignment='right',fontweight='light',fontsize='x-large')
plt.show()

# %%
#overlab some values
plt.figure(figsize=(16,8))
sns.barplot(x='Active',y='Name of State / UT',data=df1[:-1],color='lightgreen',label='Active cases')
sns.barplot(x='Recovered',y='Name of State / UT',data=df1[:-1],color='blue',label='Recovered cases')
sns.barplot(x='Deaths',y='Name of State / UT',data=df1[:-1],color='red',label='Death')
#add legend for see your lable and add location of legend
plt.legend(loc='lower right')
plt.show()
